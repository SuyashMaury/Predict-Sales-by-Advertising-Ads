# %%
import pandas
df = pandas.read_csv("cardekho.csv")

# %%
df
# Out:
#                                  Car_Name  Year  Selling_Price  Kms_Driven  \
# 0                           Maruti 800 AC  2007          60000       70000
# 1                Maruti Wagon R LXI Minor  2007         135000       50000
# 2                    Hyundai Verna 1.6 SX  2012         600000      100000
# 3                  Datsun RediGO T Option  2017         250000       46000
# 4                   Honda Amaze VX i-DTEC  2014         450000      141000
# ...                                   ...   ...            ...         ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999       80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999       80000
# 4337                  Maruti 800 AC BSIII  2009         110000       83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000       90000
# 4339                     Renault KWID RXT  2016         225000       40000
#
#      Fuel_Type Seller_Type Transmission         Owner
# ...

# %%
df.head()
# Out:
#                    Car_Name  Year  Selling_Price  Kms_Driven Fuel_Type  \
# 0             Maruti 800 AC  2007          60000       70000    Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000       50000    Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000      100000    Diesel
# 3    Datsun RediGO T Option  2017         250000       46000    Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000      141000    Diesel
#
#   Seller_Type Transmission         Owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.dtypes
# Out:
# Car_Name         object
# Year              int64
# Selling_Price     int64
# Kms_Driven        int64
# Fuel_Type        object
# Seller_Type      object
# Transmission     object
# Owner            object
# dtype: object

# %%
df.nunique()
# Out:
# Car_Name         1491
# Year               29
# Selling_Price     445
# Kms_Driven        770
# Fuel_Type           5
# Seller_Type         3
# Transmission        2
# Owner               5
# dtype: int64

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-25-2f6f6606aa2c>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                    Year  Selling_Price  Kms_Driven
# Year           1.000000       0.413963   -0.419624
# Selling_Price  0.413963       1.000000   -0.192348
# Kms_Driven    -0.419624      -0.192348    1.000000

# %%
df["Year"].max()
# Out:
# 2022

# %%
currentage=2023

# %%
df['car_age']=currentage-df['Year']

# %%
df['car_age']
# Out:
# 0       16
# 1       16
# 2       11
# 3        6
# 4        9
#         ..
# 4335     9
# 4336     9
# 4337    14
# 4338     7
# 4339     7
# Name: car_age, Length: 4340, dtype: int64

# %%
df['car_age'].max()
# Out:
# 31

# %%
df.describe()
# Out:
#               Year  Selling_Price     Kms_Driven      car_age
# count  4340.000000   4.340000e+03    4340.000000  4340.000000
# mean   2013.096774   5.043381e+05   66195.040092     9.903226
# std       4.215757   5.785445e+05   46649.084846     4.215757
# min    1992.000000   2.000000e+04       1.000000     1.000000
# 25%    2011.000000   2.100000e+05   35000.000000     7.000000
# 50%    2014.000000   3.500000e+05   60000.000000     9.000000
# 75%    2016.000000   6.000000e+05   90000.000000    12.000000
# max    2022.000000   8.900000e+06  806599.000000    31.000000

# %%
import pandas as pd

df_subset=df[['car_age','Kms_Driven']]

# %%
type(df_subset)
# Out:
# pandas.core.frame.DataFrame

# %%
df_subset
# Out:
#       car_age  Kms_Driven
# 0          16       70000
# 1          16       50000
# 2          11      100000
# 3           6       46000
# 4           9      141000
# ...       ...         ...
# 4335        9       80000
# 4336        9       80000
# 4337       14       83000
# 4338        7       90000
# 4339        7       40000
#
# [4340 rows x 2 columns]

# %%
set(df['Owner'])
# Out:
# {'First Owner',
#  'Fourth & Above Owner',
#  'Second Owner',
#  'Test Drive Car',
#  'Third Owner'}

# %%
sum_sell=df['Selling_Price'].sum()
age_sell=df.groupby('Owner')['Selling_Price'].agg(['count','sum','mean','median'])

# %%
age_sell['Owner_Weight']=age_sell['sum']/sum_sell
age_sell
# Out:
#                       count         sum           mean    median  Owner_Weight
# Owner
# First Owner            2833  1696289898  598760.994705  450000.0      0.774976
# Fourth & Above Owner     81    14085997  173901.197531  130000.0      0.006435
# Second Owner           1106   380343544  343891.088608  250499.5      0.173766
# Test Drive Car           17    16222997  954293.941176  894999.0      0.007412
# Third Owner             303    81885097  270247.844884  190000.0      0.037410

# %%
age_sell['Owner_Weight']
# Out:
# Owner
# First Owner             0.774976
# Fourth & Above Owner    0.006435
# Second Owner            0.173766
# Test Drive Car          0.007412
# Third Owner             0.037410
# Name: Owner_Weight, dtype: float64

# %%
owner_dict={'first owner'}

# %%
df['car_make']=df['Car_Name'].str.split(' ').str[0]   #df['car_make']=df['Car_Name'].str.split(n=1).str[0], tells if there is some changegs in pattern in the string
df
# Out:
#                                  Car_Name  Year  Selling_Price  Kms_Driven  \
# 0                           Maruti 800 AC  2007          60000       70000
# 1                Maruti Wagon R LXI Minor  2007         135000       50000
# 2                    Hyundai Verna 1.6 SX  2012         600000      100000
# 3                  Datsun RediGO T Option  2017         250000       46000
# 4                   Honda Amaze VX i-DTEC  2014         450000      141000
# ...                                   ...   ...            ...         ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999       80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999       80000
# 4337                  Maruti 800 AC BSIII  2009         110000       83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000       90000
# 4339                     Renault KWID RXT  2016         225000       40000
#
# ...

# %%
set(df['Fuel_Type'])
df['Fuel_Type'].value_counts()
# Out:
# Diesel      2149
# Petrol      2122
# CNG           40
# LPG           23
# Electric       6
# Name: Fuel_Type, dtype: int64

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
df['car_make']
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 4335
# 4336
# 4337
# 4338
# 4339
# Name: car_make, Length: 4340, dtype: object

# %%
fig = px.bar(data_frame=df, x=df['car_make'].value_counts().index, y=df['car_make'].value_counts().values,text_auto=True,color=df['car_make'].value_counts().index)
fig.update_layout(title='Number of car brands',xaxis_title='cars_brands',yaxis_title='Count',width=800,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(data_frame=df, x=df['Fuel_Type'].value_counts().index, y=df['Fuel_Type'].value_counts().values,text_auto=True,color=df['Fuel_Type'].value_counts().index)
fig.update_layout(title='number of cars on the basis Fuel types',xaxis_title='fuels',yaxis_title='Count',width=800,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.histogram(data_frame=df,x='Year',text_auto=True,nbins=31)
fig.update_layout(title='Number of cars sold per year',width=1000,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.histogram(data_frame=df,x='Selling_Price',text_auto=True)
fig.update_layout(title='Number of cars soldwith specific range of price')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.histogram(data_frame=df,x='Kms_Driven',text_auto=True,nbins=100)
fig.update_layout(title='Number of cars Kms_Driven with specific range of km')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(data_frame=df, x=df['Seller_Type'].value_counts().index, y=df['Seller_Type'].value_counts().values,text_auto=True,color=df['Seller_Type'].value_counts().index)
fig.update_layout(title='number of cars on the basis Seller types',xaxis_title='Seller',yaxis_title='Count',width=800,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(data_frame=df, x=df['Transmission'].value_counts().index, y=df['Transmission'].value_counts().values,text_auto=True,color=df['Transmission'].value_counts().index)
fig.update_layout(title='number of cars on the basis Transmission types',xaxis_title='Transmission Type',yaxis_title='Count',width=800,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(data_frame=df, x=df['Owner'].value_counts().index, y=df['Owner'].value_counts().values,text_auto=True,color=df['Owner'].value_counts().index)
fig.update_layout(title='number of cars on the basis Owner',xaxis_title='Owner Type',yaxis_title='Count',width=800,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(data_frame=df,x='Selling_Price',y='Fuel_Type',orientation='h', color='Fuel_Type')
fig.update_layout(title='Boxplot of selling price on the basis of fuel type')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#                                  Car_Name  Year  Selling_Price  Kms_Driven  \
# 0                           Maruti 800 AC  2007          60000       70000
# 1                Maruti Wagon R LXI Minor  2007         135000       50000
# 2                    Hyundai Verna 1.6 SX  2012         600000      100000
# 3                  Datsun RediGO T Option  2017         250000       46000
# 4                   Honda Amaze VX i-DTEC  2014         450000      141000
# ...                                   ...   ...            ...         ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999       80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999       80000
# 4337                  Maruti 800 AC BSIII  2009         110000       83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000       90000
# 4339                     Renault KWID RXT  2016         225000       40000
#
# ...

# %%
fig=px.box(data_frame=df,x='Selling_Price',y='Fuel_Type',orientation='h', color='Seller_Type')
fig.update_layout(title='Boxplot of selling price on the basis of Seller type and fuel type')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(data_frame=df,x='Selling_Price',y='Transmission',orientation='h', color='Transmission')
fig.update_layout(title='Boxplot of selling price on the basis of Transmission')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(data_frame=df,x='Selling_Price',y='Owner',orientation='h', color='Owner')
fig.update_layout(title='Boxplot of selling price on the basis of Owner')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
car_company_count= df.groupby(['car_make','Owner']).size().reset_index(name='Count')
car_company_count
# Out:
#       car_make                 Owner  Count
# 0   Ambassador  Fourth & Above Owner      1
# 1   Ambassador          Second Owner      3
# 2         Audi           First Owner     50
# 3         Audi          Second Owner      6
# 4         Audi           Third Owner      4
# ..         ...                   ...    ...
# 77  Volkswagen          Second Owner     29
# 78  Volkswagen        Test Drive Car      1
# 79  Volkswagen           Third Owner      6
# 80       Volvo           First Owner      3
# 81       Volvo           Third Owner      1
#
# [82 rows x 3 columns]
